# %%
import pretty_midi
import numpy as np
import itertools
import random
import glob
from __future__ import print_function
import tensorflow as tf
from tensorflow.contrib import rnn

#Checks current directory for the midi file extension and returns a list of all the midi files
def getMidi(folder):
    return glob.glob(folder+"/*.mid")

def chordTransform(chord): 
    #all possible triad chords
    triads = {
            'major' : [4, 3],
            'minor' : [3, 4],
            'dim' : [3, 3],
            'aug' : [4, 4]
        }
    
    #If not triad then returns a random note of the chord
    if len(chord) != 3:
        root_note = random.choice(chord)
        return root_note
    
    #Finds the corresponding notes and its root note
    root_chord = {}
    for note in chord:
        root_chord[note]= note%12
    
    # Get all possible permutations of these notes
    note_perms = list(itertools.permutations(list(root_chord.values())))

    # Test each permutation against the possible triad intervals and return the triad type if there's a match.
    for i in range(len(note_perms)-1):
        notes_intervals = []
        posRoot_note = 99
        root_note = 99

        # Loop through notes and create a list, length 2, of intervals to check against
        for j in range(len(chord)-1):
            
            #Stores the current and next note in the possible permutations
            note_A = note_perms[i][j]
            note_B = note_perms[i][j+1]
            
            #finds the interval
            interval = note_B - note_A
            
            #If the interval is negative then loops around just a different octave
            if interval < 0:
                interval = interval + 12
                
            #Store the interval
            notes_intervals.append(interval)
            
            #The lowest note is the possible root note so checks for that and stores it
            if note_A <= note_B:
                if note_A < posRoot_note:
                    posRoot_note = note_A
            if note_B <= note_A: 
                if note_B < posRoot_note:
                    posRoot_note = note_B
                    
        # Finally loop through the traids dict to see if we have a match for a triad
        for t in triads.keys():
            if triads[t] == notes_intervals:
                
                #If so the root note is the lowest note of the triad
                #This method finds a key given a value
                for real_root, pseudo_root in root_chord.items():
                    if pseudo_root == posRoot_note:
                        return real_root
            
    #If not then the root note is a random note from the collection of notes
    if root_note not in range(12):
        root_note = random.choice(list(root_chord.keys()))
        return root_note

#@inputs: note_array is a matrix that is 128xinstrument.get_piano_roll() long. The number of columns is dependent upon how
            # sample will be split by time

#@returns: a vector that contains the root note at each time sample
def instrument_to_vector(note_array):
    note_array_transpose = np.transpose(note_array)
    note_vector = np.empty(note_array.shape[1])
    note_vector.fill(-1)
    for i in range(note_array_transpose.shape[0]): #The i here will be the column number of the transpose, which is the note
                                                   #This loop should iterate through the number of columns in transpose
        note_list=[]
        for number in note_array_transpose[i]:
            if number!=-1:
                note_list.append(number) #add the number aka the note being played 
                                        # if there is no number there is no note played so that place is 0
            if len(note_list)!=1:
                note_vector[i]=-1
            else:
                note_vector[i]=note_list[0]
    return note_vector

def NoteMatrix(midi_data, samplesPerSec):
    #Defines how many samples per second
    fs = samplesPerSec

    #Returns the total amount of samples gotten
    y = np.arange(0, midi_data.get_end_time(), 1./fs).shape[0]

    #Our desired matrix has the amount of samples for every possible instrument
    #noteMatrix = np.zeros(shape=(128, y))
    noteMatrix = np.empty(shape=(128,y))
    noteMatrix.fill(-1)

    #Iterates through all the instruments of the midi song
    for instrument in midi_data.instruments:

        #Creates an array of all the notes the instrument can possibly play over a time sample and its velocity
        total_notes = np.asarray(instrument.get_piano_roll(fs=fs, times=np.arange(0, midi_data.get_end_time(), 1./fs)))
        total_notes[total_notes == 0] = -1
        
        #Holder for the final array that converts chords into notes making all instruments monophonic
        converted_notes = np.zeros(shape=total_notes.shape)

        #Goes through each time sample to see if notes repeat, if so find the root node of this chord
        i=0
        
        for column in total_notes.T:

            #Notes repeat in a time slice
            if count_nonNegOne(column) > 1:

                #create a list containing the notes played
                chord = np.where(column>=0)[0]
                
                if len(chord) > 0:
                    #finds the root note of the chord
                    root_note = chordTransform(chord)

                    #removes all other notes other than the root
                    for note in chord:
                        if note != root_note:
                            column[note] = -1

                    #Classify the time slice by the root note itself not velocity
                    column[root_note] = root_note

                #Store in the converted notes
            converted_notes[:, i] = column
            i += 1

        #As every time splice has only one note with the note defined, convert into vector
        instrument_vector = instrument_to_vector(converted_notes)

        #For that instrument store the vector of the notes played out of all
        noteMatrix[instrument.program] = instrument_vector
    return noteMatrix

#Testing purposes
def count_nonNegOne(array):
    count = 0
    for i in array:
        if i != -1:
            count += 1
    return count

#For the creation of the label array for the RNN
def get_label_vector(label):
    label_array = np.zeros((1,7))
    label_dict = {'hh':0,
                 'cl':1,
                 'cn':2,
                 'ro':3,
                 'ed':4,
                 'pp':5,
                 'mt':6}
    label_array[0][label_dict[label]] = 1
    return label_array

#def main():
    #Makes a list of all the note matrices for all midis
#    midi_note = []

    #Makes a list of all the labels for each corresponding midi's note matrix
#    midi_label = []

    #Iterates through all midis
#    for midi in getMidi():

        #Opens midi as a pretty midi file
#        midi_data = pretty_midi.PrettyMIDI(midi)

        #creates the note matrix
#        noteMatrix = NoteMatrix(midi_data, 10)

        #adds to list of matrices
#        midi_note.append(noteMatrix)

        #stores the label of the midi file which is the first two letters of each midi
#        midi_label.append(midi[:2])
        
#if __name__== "__main__":
#    main()

# %%
#Makes a list of all the note matrices for all midis
train_midi_note = []
test_midi_note = []
#Makes a list of all the labels for each corresponding midi's note matrix
train_midi_label = []
test_midi_label = []
#number of samples per second
fs = 20

print('hello')

all_midis = getMidi('mt_vs_hh_vs_ro')
print(all_midis)
#print(len(all_midis))
def get_train_and_test_data(all_midis,num_train,num_test):
    training_length=num_train
    test_length = num_test
    permutation = np.random.permutation(training_length)
    train_data = []
    for i in permutation:
        train_data.append(all_midis[i])
        
    test_data = []
    for i in all_midis:
        if i not in train_data:
            test_data.append(i)
    return train_data,test_data

train_data,test_data = get_train_and_test_data(all_midis,60,15)
print(len(test_data))
print(len(train_data))

#Iterates through all midis
for midi in train_data:

    #Opens midi as a pretty midi file
    midi_data = pretty_midi.PrettyMIDI(midi)

    #creates the note matrix
    noteMatrix = NoteMatrix(midi_data, fs)
    
    #only gets the slice from 30 seconds to 90 seconds
    start = 30*fs
    end = 90*fs
    
    #Stores sequence length for tensorflow
    sequence_length = end-start
    
    #Stores the first minute
    noteMatrix = noteMatrix[:, start:end].T
    
    #adds to list of matrices
    train_midi_note.append(noteMatrix)

    #stores the label of the midi file which is the first two letters of each midi
    abbrev = midi.split("/")[1][:2]
    train_midi_label.append(get_label_vector(abbrev))
    
    
for midi in test_data:

    #Opens midi as a pretty midi file
    midi_data = pretty_midi.PrettyMIDI(midi)

    #creates the note matrix
    noteMatrix = NoteMatrix(midi_data, fs)
    
    #only gets the slice from 30 seconds to 90 seconds
    start = 30*fs
    end = 90*fs
    
    #Stores sequence length for tensorflow
    sequence_length = end-start
    
    #Stores the first minute
    noteMatrix = noteMatrix[:, start:end].T
    
    #adds to list of matrices
    test_midi_note.append(noteMatrix)

    #stores the label of the midi file which is the first two letters of each midi
    abbrev = midi.split("/")[1][:2]
    test_midi_label.append(get_label_vector(abbrev))
# Out:
# hello
# ['mt_vs_hh_vs_ro/hh_AllTheLights.mid', 'mt_vs_hh_vs_ro/hh_Ambitionzasarida.mid', 'mt_vs_hh_vs_ro/hh_BigPoppa.mid', 'mt_vs_hh_vs_ro/hh_CaliforniaLove.mid', 'mt_vs_hh_vs_ro/hh_CandyShop.mid', 'mt_vs_hh_vs_ro/hh_Disturbia.mid', 'mt_vs_hh_vs_ro/hh_DontStopTheMusic.mid', 'mt_vs_hh_vs_ro/hh_DropItLikeItsHot.mid', 'mt_vs_hh_vs_ro/hh_EmpireStateofMind.mid', 'mt_vs_hh_vs_ro/hh_FeelGoodInc.mid', 'mt_vs_hh_vs_ro/hh_ForgotAboutDre.mid', 'mt_vs_hh_vs_ro/hh_HitEmUp.mid', 'mt_vs_hh_vs_ro/hh_Ignition.mid', 'mt_vs_hh_vs_ro/hh_IGotAFeeling.mid', 'mt_vs_hh_vs_ro/hh_JustCantGetEnough.mid', 'mt_vs_hh_vs_ro/hh_Lollipop.mid', 'mt_vs_hh_vs_ro/hh_Ms.Jackson.mid', 'mt_vs_hh_vs_ro/hh_P.I.M.P..mid', 'mt_vs_hh_vs_ro/hh_PartyUp.mid', 'mt_vs_hh_vs_ro/hh_PumpIt.mid', 'mt_vs_hh_vs_ro/hh_PutYourHandsWhereICanSeeThem.mid', 'mt_vs_hh_vs_ro/hh_RapGod.mid', 'mt_vs_hh_vs_ro/hh_Renagade.mid', 'mt_vs_hh_vs_ro/hh_RightAboveIt.mid', 'mt_vs_hh_vs_ro/hh_ToySoldiers.mid', 'mt_vs_hh_vs_ro/mt_04.Metallica-The Unforgiven.mid', 'mt_vs_hh_vs_ro/mt_05.Metallica-Where Ever I May Roam.mid', 'mt_vs_hh_vs_ro/mt_5.Metallica-Disposable Heroes.mid', 'mt_vs_hh_vs_ro/mt_6.Metallica-Leper Messiah.mid', 'mt_vs_hh_vs_ro/mt_BullsOnParade(2).mid', 'mt_vs_hh_vs_ro/mt_Carcass - Carneous Cacoffiny.mid', 'mt_vs_hh_vs_ro/mt_COB-Lake Bodom.mid', 'mt_vs_hh_vs_ro/mt_Judas Priest - The Ripper.mid', "mt_vs_hh_vs_ro/mt_Judas Priest - You've Got Another Thing Comin'.mid", 'mt_vs_hh_vs_ro/mt_Megadeth-Family Tree.mid', 'mt_vs_hh_vs_ro/mt_Megadeth-Five Magics.mid', 'mt_vs_hh_vs_ro/mt_Megadeth-I Thought I Knew It All.mid', 'mt_vs_hh_vs_ro/mt_Megadeth-Ill Get Even.mid', 'mt_vs_hh_vs_ro/mt_Megadeth-Reckoning Day.mid', 'mt_vs_hh_vs_ro/mt_Megadeth-Tornado Of Souls.mid', 'mt_vs_hh_vs_ro/mt_Ozzy Osborne-Mr Crowley.mid', 'mt_vs_hh_vs_ro/mt_Ozzy Osbourne-Suicide solution.mid', 'mt_vs_hh_vs_ro/mt_Pantera-Becoming.mid', 'mt_vs_hh_vs_ro/mt_Pantera-Cowboys From Hell.mid', 'mt_vs_hh_vs_ro/mt_Pantera-Walk.mid', 'mt_vs_hh_vs_ro/mt_Sepultura- Roots.mid', 'mt_vs_hh_vs_ro/mt_Sepultura-Arise.mid', 'mt_vs_hh_vs_ro/mt_Slayer-Angel Of Death.mid', 'mt_vs_hh_vs_ro/mt_Slayer-Dittohead.mid', 'mt_vs_hh_vs_ro/mt_Slayer-Divine Intervention.mid', 'mt_vs_hh_vs_ro/ro_Amber.mid', 'mt_vs_hh_vs_ro/ro_AmericanWomen.mid', 'mt_vs_hh_vs_ro/ro_AngryChair.mid', 'mt_vs_hh_vs_ro/ro_Animals.mid', 'mt_vs_hh_vs_ro/ro_Asshole.mid', 'mt_vs_hh_vs_ro/ro_BabyPleaseDontGo.mid', 'mt_vs_hh_vs_ro/ro_BasketCase.mid', 'mt_vs_hh_vs_ro/ro_BeautifulDisaster.mid', 'mt_vs_hh_vs_ro/ro_BigShot.mid', 'mt_vs_hh_vs_ro/ro_BlackDog.mid', 'mt_vs_hh_vs_ro/ro_BlueSky.mid', 'mt_vs_hh_vs_ro/ro_Cocaine(2).mid', 'mt_vs_hh_vs_ro/ro_DownInAHole(3).mid', 'mt_vs_hh_vs_ro/ro_DownOnTheCorner.mid', 'mt_vs_hh_vs_ro/ro_ForeplayLongTime.mid', 'mt_vs_hh_vs_ro/ro_GloryDays.mid', 'mt_vs_hh_vs_ro/ro_GoodTimesBadTimes.mid', 'mt_vs_hh_vs_ro/ro_HaveYouEverSeenTheRain.mid', 'mt_vs_hh_vs_ro/ro_Lithium.mid', 'mt_vs_hh_vs_ro/ro_ManInTheBox.mid', 'mt_vs_hh_vs_ro/ro_MidnightRider.mid', 'mt_vs_hh_vs_ro/ro_MoreThanAFeeling.mid', 'mt_vs_hh_vs_ro/ro_MrJones.mid', 'mt_vs_hh_vs_ro/ro_RambleOn.mid', 'mt_vs_hh_vs_ro/ro_RamblinMan.mid', 'mt_vs_hh_vs_ro/ro_SmellsLikeTeenSpirit.mid']
# 16
# 60
# /Users/nicholastorba/anaconda/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)

# %%
# Training Parameters
learning_rate = 0.0001
training_steps = 500
batch_size = 1
display_step = 10

# Network Parameters
num_input = 128 #instruments
timesteps = 60*fs # timesteps
num_hidden = 50 # hidden layer num of features
num_classes = 7 #Total amount of genres

# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# %%
# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}

# %%
def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    #Dropout
    lstm_cell = rnn.DropoutWrapper(lstm_cell, output_keep_prob=0.8)
    
    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %%
logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:
    
    # Run the initializer
    sess.run(init)

    for step in range(1, training_steps+1):
        for i in range(1,len(train_midi_note)):
            batch_x = train_midi_note[i]
            batch_y = train_midi_label[i]
            if(batch_x.shape[0]!=(60*fs)):
                continue
            # Reshape data to get 60*fs seq of 128 elements
            batch_x = batch_x.reshape((batch_size, timesteps, num_input))
            # Run optimization op (backprop)
            sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
            if step % display_step == 0 or step == 1:
                # Calculate batch loss and accuracy
                loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                     Y: batch_y})
                print("Step " + str(step) + ", Minibatch Loss= " + \
                      "{:.4f}".format(loss) + ", Training Accuracy= " + \
                      "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for test
    for i in range(15):
        test_data = test_midi_note[i]
        test_label = test_midi_label[i]
        if (test_data.shape[0] != (60*fs)):
            continue
        # Reshape data to get 60*fs seq of 128 elements
        test_data = test_data.reshape((batch_size, timesteps, num_input))
        print("Testing Accuracy:", \
            sess.run(accuracy, feed_dict={X: test_data, Y: test_label}))
# Out:
# Step 1, Minibatch Loss= 2.5932, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 4.9261, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 5.4477, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 13.4318, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 2.1121, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 3.2801, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 6.9764, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.8911, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.6918, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0493, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0570, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 1.6574, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 6.4792, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 6.0561, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.6071, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.2300, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 6.6828, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.2975, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 11.6356, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 7.5739, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 6.4285, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 10.0298, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.8864, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 7.3155, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 10.7868, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.7819, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 6.5570, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 11.2709, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.0473, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 3.2553, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.2266, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.6442, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 3.3839, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.0075, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.0805, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 2.8107, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.8906, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 9.7930, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 2.8348, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.5849, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.3407, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 0.5503, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 7.5702, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 9.5797, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 4.9788, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.4941, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 2.4540, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.0955, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 3.1742, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 5.1527, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 5.7229, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 3.9820, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 1.1592, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 5.2573, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 2.9307, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 0.0067, Training Accuracy= 1.000
# Step 1, Minibatch Loss= 5.0830, Training Accuracy= 0.000
# Step 1, Minibatch Loss= 6.4975, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 1.6189, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.8107, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 2.6590, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 1.5936, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 2.0343, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 1.5671, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.1611, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 2.3525, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 3.3679, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.2920, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0022, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.7852, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 1.1135, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0260, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 2.6902, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0781, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.3013, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.6529, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.2811, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 4.9641, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 5.2648, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.3374, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 2.2027, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0802, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 8.1904, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 5.5056, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0715, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.4150, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 6.7836, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0053, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.1847, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0878, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.1897, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 1.9829, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.1593, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0451, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 2.0938, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0516, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 4.7284, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0489, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0284, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0704, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.3982, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 4.5522, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 2.1408, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0951, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.2542, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0806, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.2465, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0551, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 1.8918, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 0.0960, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.6516, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 1.2662, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.2837, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 10, Minibatch Loss= 0.9909, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 3.8490, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 2.9010, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.2645, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.3033, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 2.8497, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0112, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 2.1077, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 1.3241, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.8641, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 1.0244, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.2811, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0186, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.6783, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0119, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0266, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.4324, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.5785, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.4584, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 3.8164, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 1.8235, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 6.1458, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 4.7511, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.6363, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.7554, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0188, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 4.4631, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 6.0432, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0221, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.2039, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 3.8941, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.6502, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0484, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.5372, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0722, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0207, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.0233, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0893, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 1.0326, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0256, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.3838, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0063, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0079, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 2.9087, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 2.2387, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 4.4253, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.2251, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.5991, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.0260, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.3531, Training Accuracy= 1.000
# Step 20, Minibatch Loss= 0.7795, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 0.
Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0466, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.1498, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0101, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0068, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 1.8086, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 0.6727, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 1.8966, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 1.9393, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 0.0157, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0039, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.3357, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.2127, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0210, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0926, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0308, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0074, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 1.0834, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 0.0981, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.4775, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0056, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0085, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.4739, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0740, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.1264, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0231, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 5.3577, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 0.7130, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0088, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0491, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0102, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0060, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.1030, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.1496, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0106, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0117, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.9310, Training Accuracy= 0.000
# Step 130, Minibatch Loss= 0.0524, Training Accuracy= 1.000
# Step 130, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# ...
# Step 460, Minibatch Loss= 0.0150, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0578, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.4181, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.1009, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0529, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0410, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.2419, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.2601, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 1.9065, Training Accuracy= 0.000
# Step 460, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0105, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0054, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0317, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0151, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0328, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.0129, Training Accuracy= 1.000
# Step 460, Minibatch Loss= 0.2536, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0130, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.1023, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0473, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.4227, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.3130, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0147, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0036, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0090, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0685, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.1978, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0279, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0214, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.9805, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0177, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 2.3365, Training Accuracy= 0.000
# Step 470, Minibatch Loss= 0.0300, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0218, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0741, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0095, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0229, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.2244, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0078, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0140, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0800, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0116, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.9405, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 3.1898, Training Accuracy= 0.000
# Step 470, Minibatch Loss= 0.5051, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0092, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0093, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0522, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.1537, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0245, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0169, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0222, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0294, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 470, Minibatch Loss= 0.6020, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0165, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0719, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0163, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.3374, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0450, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1186, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0126, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0172, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0057, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0123, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0061, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0149, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0113, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1758, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.2723, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 2.5168, Training Accuracy= 0.000
# Step 480, Minibatch Loss= 0.1445, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0083, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0042, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0218, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0089, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.4014, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0066, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0183, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0089, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1274, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0052, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0297, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0629, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0248, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1314, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0026, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1092, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 1.4609, Training Accuracy= 0.000
# Step 480, Minibatch Loss= 0.0062, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0324, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0343, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.6533, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0686, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.5666, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.1081, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0044, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0070, Training Accuracy= 1.000
# Step 480, Minibatch Loss= 0.0141, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0127, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0706, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0163, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 1.2150, Training Accuracy= 0.000
# Step 490, Minibatch Loss= 0.0021, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0385, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.1104, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0057, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0055, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0255, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0321, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0864, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0990, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.8860, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 3.2961, Training Accuracy= 0.000
# Step 490, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0069, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.2693, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0038, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0043, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.1746, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0281, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.2368, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0126, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0765, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.3746, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 1.3448, Training Accuracy= 0.000
# Step 490, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0021, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0249, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0113, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0845, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0061, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.3078, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0444, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 490, Minibatch Loss= 0.1366, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0030, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0320, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0268, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 1.6954, Training Accuracy= 0.000
# Step 500, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0032, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.1705, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.2410, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0094, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0376, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0428, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.2509, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0075, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.9355, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 2.8062, Training Accuracy= 0.000
# Step 500, Minibatch Loss= 0.0035, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0018, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.9954, Training Accuracy= 0.000
# Step 500, Minibatch Loss= 0.0126, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0152, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0467, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0191, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0149, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0121, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0162, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.5548, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0034, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.4630, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.8620, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 1.0018, Training Accuracy= 0.000
# Step 500, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0083, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0107, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0029, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0082, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0474, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.2130, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0656, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0129, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Step 500, Minibatch Loss= 0.2470, Training Accuracy= 1.000
# Optimization Finished!
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 1.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0
# Testing Accuracy: 0.0

# %%
train_midi_note[7]
